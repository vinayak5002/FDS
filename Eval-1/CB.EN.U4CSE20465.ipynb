# %%
import numpy as np
import pandas as pd

# %%
# 1

df = pd.read_csv("Cereals.csv")

# %%
# 2

df.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  76.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.802632
# std     19.484119   1.094790   1.006473   83.832295   2.383364   3.907326
# min     50.000000   1.000000   0.000000    0.000000   0.000000   5.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.500000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  76.000000   75.000000   77.000000  77.000000  77.000000  77.000000
# mean    7.026316   98.666667   28.246753   2.207792   1.029610   0.821039
# std     4.378656   70.410636   22.342523   0.832524   0.150477   0.232716
# ...

# %%
# 3

df.head(3)
# Out:
#                 name mfr type  calories  protein  fat  sodium  fiber  carbo  \
# 0          100%_Bran   N    C        70        4    1     130   10.0    5.0
# 1  100%_Natural_Bran   Q    C       120        3    5      15    2.0    8.0
# 2           All-Bran   K    C        70        4    1     260    9.0    7.0
#
#    sugars  potass  vitamins  shelf  weight  cups     rating
# 0     6.0   280.0        25      3     1.0  0.33  68.402973
# 1     8.0   135.0         0      3     1.0  1.00  33.983679
# 2     5.0   320.0        25      3     1.0  0.33  59.425505

# %%
# 4

df.rename(columns={'mfr' : 'manufacturer'}, inplace= True)
df.head()
# Out:
#                         name manufacturer type  calories  protein  fat  \
# 0                  100%_Bran            N    C        70        4    1
# 1          100%_Natural_Bran            Q    C       120        3    5
# 2                   All-Bran            K    C        70        4    1
# 3  All-Bran_with_Extra_Fiber            K    C        50        4    0
# 4             Almond_Delight            R    C       110        2    2
#
#    sodium  fiber  carbo  sugars  potass  vitamins  shelf  weight  cups  \
# 0     130   10.0    5.0     6.0   280.0        25      3     1.0  0.33
# 1      15    2.0    8.0     8.0   135.0         0      3     1.0  1.00
# 2     260    9.0    7.0     5.0   320.0        25      3     1.0  0.33
# 3     140   14.0    8.0     0.0   330.0        25      3     1.0  0.50
# 4     200    1.0   14.0     8.0     NaN        25      3     1.0  0.75
#
#       rating
# 0  68.402973
# 1  33.983679
# 2  59.425505
# 3  93.704912
# 4  34.384843

# %%
# 5

df[df['calories'] > 80]['name']
# Out:
# 1           100%_Natural_Bran
# 4              Almond_Delight
# 5     Apple_Cinnamon_Cheerios
# 6                 Apple_Jacks
# 7                     Basic_4
#                ...
# 72                    Triples
# 73                       Trix
# 74                 Wheat_Chex
# 75                   Wheaties
# 76        Wheaties_Honey_Gold
# Name: name, Length: 71, dtype: object

# %%
# 6

print(df.loc[df['calories'] > 80]['name'])

print(df.iloc[:10, :])
# Out:
# 1           100%_Natural_Bran
# 4              Almond_Delight
# 5     Apple_Cinnamon_Cheerios
# 6                 Apple_Jacks
# 7                     Basic_4
#                ...
# 72                    Triples
# 73                       Trix
# 74                 Wheat_Chex
# 75                   Wheaties
# 76        Wheaties_Honey_Gold
# Name: name, Length: 71, dtype: object
#                         name manufacturer type  calories  protein  fat  \
# 0                  100%_Bran            N    C        70        4    1
# 1          100%_Natural_Bran            Q    C       120        3    5
# 2                   All-Bran            K    C        70        4    1
# 3  All-Bran_with_Extra_Fiber            K    C        50        4    0
# 4             Almond_Delight            R    C       110        2    2
# 5    Apple_Cinnamon_Cheerios            G    C       110        2    2
# 6                Apple_Jacks            K    C       110        2    0
# ...

# %%
# 7

df[df['fat'] > 2].shape[0]
# Out:
# 6

# %%
# 8

df.groupby(['manufacturer']).count()
# Out:
#               name  type  calories  protein  fat  sodium  fiber  carbo  \
# manufacturer
# A                1     1         1        1    1       1      1      1
# G               22    22        22       22   22      22     22     22
# K               23    23        23       23   23      23     23     23
# N                6     6         6        6    6       6      6      6
# P                9     9         9        9    9       9      9      9
# Q                8     8         8        8    8       8      8      7
# R                8     8         8        8    8       8      8      8
#
#               sugars  potass  vitamins  shelf  weight  cups  rating
# manufacturer
# A                  1       1         1      1       1     1       1
# G                 22      22        22     22      22    22      22
# K                 23      23        23     23      23    23      23
# N                  6       5         6      6       6     6       6
# ...

# %%
# 9

df['manufacturer'].value_counts()
# Out:
# K    23
# G    22
# P     9
# Q     8
# R     8
# N     6
# A     1
# Name: manufacturer, dtype: int64

# %%
# 10

df[df['protein'] > 2]
# Out:
#                                       name manufacturer type  calories  \
# 0                                100%_Bran            N    C        70
# 1                        100%_Natural_Bran            Q    C       120
# 2                                 All-Bran            K    C        70
# 3                All-Bran_with_Extra_Fiber            K    C        50
# 7                                  Basic_4            G    C       130
# 9                              Bran_Flakes            P    C        90
# 11                                Cheerios            G    C       110
# 13                                Clusters            G    C       110
# 19                      Cracklin'_Oat_Bran            K    C       110
# 20                  Cream_of_Wheat_(Quick)            N    H       100
# 26                     Frosted_Mini-Wheats            K    C       100
# 27  Fruit_&_Fibre_Dates,_Walnuts,_and_Oats            P    C       120
# ...

# %%
# 11

df[df['fiber'] > 2].groupby('manufacturer', group_keys= True).apply(lambda x:x)
# Out:
#                                                    name manufacturer type  \
# manufacturer
# G            59                         Raisin_Nut_Bran            G    C
#              70                       Total_Raisin_Bran            G    C
#              71                       Total_Whole_Grain            G    C
#              75                                Wheaties            G    C
# K            2                                 All-Bran            K    C
#              3                All-Bran_with_Extra_Fiber            K    C
#              19                      Cracklin'_Oat_Bran            K    C
#              26                     Frosted_Mini-Wheats            K    C
#              28                           Fruitful_Bran            K    C
#              46                    Mueslix_Crispy_Blend            K    C
#              49               Nutri-Grain_Almond-Raisin            K    C
# ...

# %%
# 12

fiber = df['fiber'].describe()

print(f'Count : {fiber["count"]} \nMean : {fiber["mean"]} \nStandard Deviation : {fiber["std"]}')
print(f'Maximum : {fiber["max"]} \nMinimum : {fiber["min"]}')
print(f'Q1 : {fiber["25%"]} \nQ2 : {fiber["50%"]} \nQ3 : {fiber["75%"]} ')
# Out:
# Count : 77.0
# Mean : 2.1519480519480516
# Standard Deviation : 2.383363964387222
# Maximum : 14.0
# Minimum : 0.0
# Q1 : 1.0
# Q2 : 2.0
# Q3 : 3.0

# %%
# 13

df['fat'].median()
# Out:
# 1.0

# %%
# 14

# 14. Find the median of an attribute  'rating' and select details of cereals with "rating" > 40 


df[df['rating'] > 40]['rating'].median()
# Out:
# 50.7966955

# %%
import matplotlib.pyplot as plt

# %%
# 15

pmf = df['sugars'].value_counts().sort_index() / df['sugars'].shape[0]
pmf.plot(kind= 'bar')
# Out:
# <AxesSubplot: >

# %%
# 16

(df['fiber'] - df['carbo']).mean()
# Out:
# -12.657894736842104

# %%
# 17

plt.boxplot(df['sodium'])
plt.show()

# %%
# 18

plt.hist(df['calories'], bins= range(0, 170, 10))
plt.show()

# From the histogram, we can say that the 'calories' is left skewd

# %%
# 19

df.kurt(axis= 0)['sugars']
# Out:
# /tmp/ipykernel_8699/3468714431.py:3: FutureWarning: The default value of numeric_only in DataFrame.kurt is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.kurt(axis= 0)['sugars']
# -1.153358847980711

# %%
# 20

df['potass'].isnull().sum()
# Out:
# 2

# %%
df['potass'].fillna(df['potass'].mean(), inplace= True)

# %%
df['potass'].isnull().sum()
# Out:
# 0
